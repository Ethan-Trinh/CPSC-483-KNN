# %%
# Python Version 3.10.6
import numpy as np # Numpy 1.24.2
import pandas as pd # Pandas 1.5.3
from collections import Counter # 
import matplotlib.pyplot as plot # Matplotlib 3.7.0

# %%
# Import and reorder CSV file
# Row 0 was skipped because row 0 was the row label

df = pd.read_csv('HappinessData-1.csv', skiprows=[0], names=['Unhappy/Happy', 'City Services Availability', 'Housing Cost', 
                                                            'Quality of schools', 'Community trust in local police', 
                                                            'Community Maintenance', 'Availability of Community Room '])
df
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 0                1                           5             3
# 1                0                           5             3
# 2                0                           4             3
# 3                0                           4             1
# 4                1                           3             2
# ..             ...                         ...           ...
# 135              1                           4             3
# 136              0                           3             4
# 137              1                           3             3
# 138              1                           3             3
# 139              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 0                   3.0                              3.0
# 1                   3.0                              3.0
# 2                   3.0                              3.0
# 3                   3.0                              4.0
# 4                   4.0                              4.0
# ..                  ...                              ...
# 135                 3.0                              3.0
# 136                 3.0                              3.0
# 137                 3.0                              5.0
# 138                 1.0                              3.0
# 139                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 0                        5                                3
# 1                        5                                3
# 2                        4                                4
# 3                        4                                5
# 4                        4                                5
# ..                     ...                              ...
# 135                      3                                4
# 136                      2                                3
# 137                      5                                5
# 138                      3                                4
# 139                      3                                4
#
# [140 rows x 7 columns]

# %%
# Process data for any NaN
# First locate all NaN in dataset
nan_row = df[df.isnull().any(axis=1)]
nan_row
# Out:
#     Unhappy/Happy  City Services Availability  Housing Cost  \
# 5               1                           3             2
# 18              1                           5             3
# 27              1                           4             3
# 31              1                           5             3
#
#     Quality of schools  Community trust in local police  \
# 5                  4.0                              NaN
# 18                 4.0                              NaN
# 27                 NaN                              4.0
# 31                 NaN                              5.0
#
#     Community Maintenance  Availability of Community Room
# 5                       4                                5
# 18                      4                                5
# 27                      3                                4
# 31                      4                                5

# %%
# Calculate Mean and Median of each column
# Analyze data and figure out best value to fill NaN
print(df.mean(numeric_only=True))
print("\n")
print(df.median(numeric_only=True))
# Out:
# Unhappy/Happy                      0.535714
# City Services Availability         4.321429
# Housing Cost                       2.542857
# Quality of schools                 3.253623
# Community trust in local police    3.695652
# Community Maintenance              3.600000
# Availability of Community Room     4.221429
# dtype: float64
#
#
# Unhappy/Happy                      1.0
# City Services Availability         5.0
# Housing Cost                       3.0
# Quality of schools                 3.0
# Community trust in local police    4.0
# Community Maintenance              4.0
# Availability of Community Room     4.0
# dtype: float64

# %%
# Looking at the data, Mean, Median and Mode are all close enough to each other
# Replace NaN with Median, because unlike Mean (Median is a whole number and is based on frequency)

df = df.fillna(df.median())

# Check for nan rows 1 more time
nan_row2 = df[df.isnull().any(axis=1)]
nan_row2
# Out:
# Empty DataFrame
# Columns: [Unhappy/Happy, City Services Availability, Housing Cost, Quality of schools, Community trust in local police, Community Maintenance, Availability of Community Room ]
# Index: []

# %%
# Remove Duplicate rows in the data
# First find all of the duplicated rows

duplicateRows = df[df.duplicated()]
duplicateRows
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 5                1                           3             2
# 9                1                           5             3
# 23               1                           5             1
# 24               1                           5             1
# 26               1                           5             2
# 36               1                           5             2
# 39               1                           4             1
# 45               1                           4             3
# 64               0                           4             1
# 75               1                           5             5
# 103              1                           5             1
# 110              1                           5             3
# 117              0                           5             4
# 120              1                           5             4
# 132              0                           4             2
# 139              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 5                   4.0                              4.0
# 9                   4.0                              3.0
# 23                  3.0                              3.0
# 24                  3.0                              3.0
# 26                  4.0                              3.0
# 36                  4.0                              4.0
# 39                  3.0                              4.0
# 45                  3.0                              4.0
# 64                  3.0                              4.0
# 75                  5.0                              5.0
# 103                 5.0                              5.0
# 110                 3.0                              4.0
# 117                 3.0                              3.0
# 120                 4.0                              4.0
# 132                 4.0                              4.0
# 139                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 5                        4                                5
# 9                        4                                5
# 23                       4                                4
# 24                       4                                4
# 26                       4                                5
# 36                       5                                5
# 39                       4                                4
# 45                       3                                4
# 64                       4                                3
# 75                       5                                5
# 103                      5                                5
# 110                      4                                5
# 117                      3                                5
# 120                      4                                5
# 132                      4                                4
# 139                      3                                4

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 0                1                           5             3
# 1                0                           5             3
# 2                0                           4             3
# 3                0                           4             1
# 4                1                           3             2
# ..             ...                         ...           ...
# 134              1                           5             1
# 135              1                           4             3
# 136              0                           3             4
# 137              1                           3             3
# 138              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 0                   3.0                              3.0
# 1                   3.0                              3.0
# 2                   3.0                              3.0
# 3                   3.0                              4.0
# 4                   4.0                              4.0
# ..                  ...                              ...
# 134                 2.0                              5.0
# 135                 3.0                              3.0
# 136                 3.0                              3.0
# 137                 3.0                              5.0
# 138                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 0                        5                                3
# 1                        5                                3
# 2                        4                                4
# 3                        4                                5
# 4                        4                                5
# ..                     ...                              ...
# 134                      2                                4
# 135                      3                                4
# 136                      2                                3
# 137                      5                                5
# 138                      3                                4
#
# [124 rows x 7 columns]

# %%
# Unhappy/Happy is the class label: as per specifications, move the class label to the last column
# Save reference to column
class_label = df['Unhappy/Happy']
class_label
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 134    1
# 135    1
# 136    0
# 137    1
# 138    1
# Name: Unhappy/Happy, Length: 124, dtype: int64

# %%
# drop class label column
df.drop('Unhappy/Happy', axis=1, inplace=True)
df
# Out:
#      City Services Availability  Housing Cost  Quality of schools  \
# 0                             5             3                 3.0
# 1                             5             3                 3.0
# 2                             4             3                 3.0
# 3                             4             1                 3.0
# 4                             3             2                 4.0
# ..                          ...           ...                 ...
# 134                           5             1                 2.0
# 135                           4             3                 3.0
# 136                           3             4                 3.0
# 137                           3             3                 3.0
# 138                           3             3                 1.0
#
#      Community trust in local police  Community Maintenance  \
# 0                                3.0                      5
# 1                                3.0                      5
# 2                                3.0                      4
# 3                                4.0                      4
# 4                                4.0                      4
# ..                               ...                    ...
# 134                              5.0                      2
# 135                              3.0                      3
# 136                              3.0                      2
# 137                              5.0                      5
# 138                              3.0                      3
#
#      Availability of Community Room
# 0                                  3
# 1                                  3
# 2                                  4
# 3                                  5
# 4                                  5
# ..                               ...
# 134                                4
# 135                                4
# 136                                3
# 137                                5
# 138                                4
#
# [124 rows x 6 columns]

# %%
# add new column to end of table
df['Unhappy/Happy'] = class_label
df
# Out:
#      City Services Availability  Housing Cost  Quality of schools  \
# 0                             5             3                 3.0
# 1                             5             3                 3.0
# 2                             4             3                 3.0
# 3                             4             1                 3.0
# 4                             3             2                 4.0
# ..                          ...           ...                 ...
# 134                           5             1                 2.0
# 135                           4             3                 3.0
# 136                           3             4                 3.0
# 137                           3             3                 3.0
# 138                           3             3                 1.0
#
#      Community trust in local police  Community Maintenance  \
# 0                                3.0                      5
# 1                                3.0                      5
# 2                                3.0                      4
# 3                                4.0                      4
# 4                                4.0                      4
# ..                               ...                    ...
# 134                              5.0                      2
# 135                              3.0                      3
# 136                              3.0                      2
# 137                              5.0                      5
# 138                              3.0                      3
#
#      Availability of Community Room   Unhappy/Happy
# 0                                  3              1
# 1                                  3              0
# 2                                  4              0
# 3                                  5              0
# 4                                  5              1
# ..                               ...            ...
# 134                                4              1
# 135                                4              1
# 136                                3              0
# 137                                5              1
# 138                                4              1
#
# [124 rows x 7 columns]

# %%
# Split the dataframe to training set and dataset.
# Using an 80% - 20% split

df_train = df.sample(frac=0.8)
df_test = df.drop(df_train.index)

# %%
# reindex set, then print
# df_train.sort_index(ascending=True, inplace=True)
df_train.reset_index(drop=True, inplace=True)
df_train
# Out:
#     City Services Availability  Housing Cost  Quality of schools  \
# 0                            5             3                 3.0
# 1                            5             3                 3.0
# 2                            4             3                 3.0
# 3                            5             3                 2.0
# 4                            5             3                 3.0
# ..                         ...           ...                 ...
# 94                           5             1                 1.0
# 95                           5             1                 5.0
# 96                           4             1                 3.0
# 97                           4             2                 3.0
# 98                           3             2                 2.0
#
#     Community trust in local police  Community Maintenance  \
# 0                               5.0                      4
# 1                               3.0                      5
# 2                               4.0                      3
# 3                               5.0                      5
# 4                               3.0                      3
# ..                              ...                    ...
# 94                              5.0                      3
# 95                              5.0                      5
# 96                              4.0                      4
# 97                              3.0                      4
# 98                              3.0                      3
#
#     Availability of Community Room   Unhappy/Happy
# 0                                 5              1
# 1                                 3              0
# 2                                 4              1
# 3                                 5              0
# 4                                 5              1
# ..                              ...            ...
# 94                                5              0
# 95                                5              1
# 96                                3              0
# 97                                4              0
# 98                                3              0
#
# [99 rows x 7 columns]

# %%
# reindex the testset
df_test.reset_index(drop=True, inplace=True)
df_test
# Out:
#     City Services Availability  Housing Cost  Quality of schools  \
# 0                            4             3                 3.0
# 1                            4             1                 3.0
# 2                            3             2                 4.0
# 3                            4             4                 3.0
# 4                            5             2                 4.0
# 5                            5             2                 4.0
# 6                            5             2                 3.0
# 7                            3             2                 3.0
# 8                            4             2                 4.0
# 9                            5             3                 2.0
# 10                           4             3                 4.0
# 11                           3             3                 1.0
# 12                           5             4                 5.0
# 13                           5             3                 2.0
# 14                           3             1                 2.0
# 15                           5             2                 3.0
# 16                           4             1                 3.0
# 17                           4             2                 4.0
# 18                           5             2                 4.0
# 19                           3             2                 3.0
# 20                           4             4                 4.0
# 21                           5             2                 3.0
# 22                           4             1                 4.0
# 23                           4             4                 3.0
# 24                           3             3                 3.0
#
#     Community trust in local police  Community Maintenance  \
# 0                               3.0                      4
# 1                               4.0                      4
# 2                               4.0                      4
# 3                               4.0                      2
# 4                               3.0                      4
# 5                               4.0                      5
# 6                               3.0                      2
# 7                               3.0                      4
# 8                               4.0                      4
# 9                               4.0                      4
# 10                              4.0                      2
# 11                              3.0                      2
# 12                              4.0                      5
# 13                              4.0                      4
# 14                              3.0                      3
# 15                              3.0                      3
# 16                              5.0                      3
# 17                              4.0                      4
# 18                              4.0                      2
# 19                              3.0                      5
# 20                              4.0                      1
# 21                              4.0                      2
# 22                              4.0                      4
# 23                              4.0                      4
# 24                              5.0                      5
#
#     Availability of Community Room   Unhappy/Happy
# 0                                 4              0
# 1                                 5              0
# 2                                 5              1
# 3                                 4              1
# 4                                 5              1
# 5                                 5              1
# 6                                 5              0
# 7                                 4              0
# 8                                 4              1
# 9                                 4              1
# 10                                4              0
# 11                                3              0
# 12                                4              1
# 13                                5              1
# 14                                1              0
# 15                                5              0
# 16                                5              0
# 17                                4              0
# 18                                3              1
# 19                                4              0
# 20                                3              0
# 21                                5              1
# 22                                4              0
# 23                                4              0
# 24                                5              1

# %%
# Proccess the data such that relevent features are kept and irrelevent features are dropped
# Create a correlation matrix for the Training set
correlation_matrix = df_train.corr()
correlation_matrix
# Out:
#                                  City Services Availability  Housing Cost  \
# City Services Availability                         1.000000      0.079741
# Housing Cost                                       0.079741      1.000000
# Quality of schools                                 0.281873      0.223599
# Community trust in local police                    0.126753      0.103405
# Community Maintenance                              0.516276      0.040754
# Availability of Community Room                     0.422578     -0.005283
# Unhappy/Happy                                      0.308292      0.001606
#
#                                  Quality of schools  \
# City Services Availability                 0.281873
# Housing Cost                               0.223599
# Quality of schools                         1.000000
# Community trust in local police            0.237201
# Community Maintenance                      0.307723
# Availability of Community Room             0.152546
# Unhappy/Happy                              0.165746
#
#                                  Community trust in local police  \
# City Services Availability                              0.126753
# Housing Cost                                            0.103405
# Quality of schools                                      0.237201
# Community trust in local police                         1.000000
# Community Maintenance                                   0.276230
# Availability of Community Room                          0.194743
# Unhappy/Happy                                           0.113974
#
#                                  Community Maintenance  \
# City Services Availability                    0.516276
# Housing Cost                                  0.040754
# Quality of schools                            0.307723
# Community trust in local police               0.276230
# Community Maintenance                         1.000000
# Availability of Community Room                0.298581
# Unhappy/Happy                                 0.181962
#
#                                  Availability of Community Room   \
# City Services Availability                              0.422578
# Housing Cost                                           -0.005283
# Quality of schools                                      0.152546
# Community trust in local police                         0.194743
# Community Maintenance                                   0.298581
# Availability of Community Room                          1.000000
# Unhappy/Happy                                           0.169342
#
#                                  Unhappy/Happy
# City Services Availability            0.308292
# Housing Cost                          0.001606
# Quality of schools                    0.165746
# Community trust in local police       0.113974
# Community Maintenance                 0.181962
# Availability of Community Room        0.169342
# Unhappy/Happy                         1.000000

# %%
# Calculates the distance between two points
def euclidian_distance(x1, x2):
    distance = np.sqrt(np.sum((x1-x2)**2))
    return distance

# %%
class KNN:
    def __init__(self, k):
        self.k = k
        
    def fit(self, X_train, Y_train):
        self.x = X_train
        self.y = Y_train
        
    def predict(self, X_Test):
        predictions = [self._predict(x) for x in X]
        return predictions
    
    def _predict(self, x):
        # Compute Distance
        distances = [euclidian_distance(x, x_train) for x_train in self.X_train]
        
        # Closest K
        np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        
        # majority vote
        most_common = Counter(k_nearest_labels).most_common()
        return most_common

# %%
nearest_neighbor = KNN(k=5)
nearest_neighbor.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 nearest_neighbor = KNN(k=5)
# ----> 2 nearest_neighbor.fit()
#
# TypeError: KNN.fit() missing 2 required positional arguments: 'X_train' and 'Y_train'
