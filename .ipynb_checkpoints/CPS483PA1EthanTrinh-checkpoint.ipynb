# %%
# Python Version 3.10.6
import numpy as np # Numpy 1.24.2
import pandas as pd # Pandas 1.5.3
from collections import Counter # 
import matplotlib.pyplot as plot # Matplotlib 3.7.0

# %%
# Import and reorder CSV file
# Row 0 was skipped because row 0 was the row label

df = pd.read_csv('HappinessData-1.csv', skiprows=[0], names=['Unhappy/Happy', 'City Services Availability', 'Housing Cost', 
                                                            'Quality of schools', 'Community trust in local police', 
                                                            'Community Maintenance', 'Availability of Community Room '])
df
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 0                1                           5             3
# 1                0                           5             3
# 2                0                           4             3
# 3                0                           4             1
# 4                1                           3             2
# ..             ...                         ...           ...
# 135              1                           4             3
# 136              0                           3             4
# 137              1                           3             3
# 138              1                           3             3
# 139              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 0                   3.0                              3.0
# 1                   3.0                              3.0
# 2                   3.0                              3.0
# 3                   3.0                              4.0
# 4                   4.0                              4.0
# ..                  ...                              ...
# 135                 3.0                              3.0
# 136                 3.0                              3.0
# 137                 3.0                              5.0
# 138                 1.0                              3.0
# 139                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 0                        5                                3
# 1                        5                                3
# 2                        4                                4
# 3                        4                                5
# 4                        4                                5
# ..                     ...                              ...
# 135                      3                                4
# 136                      2                                3
# 137                      5                                5
# 138                      3                                4
# 139                      3                                4
#
# [140 rows x 7 columns]

# %%
# Process data for any NaN
# First locate all NaN in dataset
nan_row = df[df.isnull().any(axis=1)]
nan_row
# Out:
#     Unhappy/Happy  City Services Availability  Housing Cost  \
# 5               1                           3             2
# 18              1                           5             3
# 27              1                           4             3
# 31              1                           5             3
#
#     Quality of schools  Community trust in local police  \
# 5                  4.0                              NaN
# 18                 4.0                              NaN
# 27                 NaN                              4.0
# 31                 NaN                              5.0
#
#     Community Maintenance  Availability of Community Room
# 5                       4                                5
# 18                      4                                5
# 27                      3                                4
# 31                      4                                5

# %%
# Calculate Mean and Median of each column
# Analyze data and figure out best value to fill NaN
print(df.mean(numeric_only=True))
print("\n")
print(df.median(numeric_only=True))
# Out:
# Unhappy/Happy                      0.535714
# City Services Availability         4.321429
# Housing Cost                       2.542857
# Quality of schools                 3.253623
# Community trust in local police    3.695652
# Community Maintenance              3.600000
# Availability of Community Room     4.221429
# dtype: float64
#
#
# Unhappy/Happy                      1.0
# City Services Availability         5.0
# Housing Cost                       3.0
# Quality of schools                 3.0
# Community trust in local police    4.0
# Community Maintenance              4.0
# Availability of Community Room     4.0
# dtype: float64

# %%
# Looking at the data, Mean, Median and Mode are all close enough to each other
# Replace NaN with Median, because unlike Mean (Median is a whole number and is based on frequency)

df = df.fillna(df.median())

# Check for nan rows 1 more time
nan_row2 = df[df.isnull().any(axis=1)]
nan_row2
# Out:
# Empty DataFrame
# Columns: [Unhappy/Happy, City Services Availability, Housing Cost, Quality of schools, Community trust in local police, Community Maintenance, Availability of Community Room ]
# Index: []

# %%
# Remove Duplicate rows in the data
# First find all of the duplicated rows

duplicateRows = df[df.duplicated()]
duplicateRows
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 5                1                           3             2
# 9                1                           5             3
# 23               1                           5             1
# 24               1                           5             1
# 26               1                           5             2
# 36               1                           5             2
# 39               1                           4             1
# 45               1                           4             3
# 64               0                           4             1
# 75               1                           5             5
# 103              1                           5             1
# 110              1                           5             3
# 117              0                           5             4
# 120              1                           5             4
# 132              0                           4             2
# 139              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 5                   4.0                              4.0
# 9                   4.0                              3.0
# 23                  3.0                              3.0
# 24                  3.0                              3.0
# 26                  4.0                              3.0
# 36                  4.0                              4.0
# 39                  3.0                              4.0
# 45                  3.0                              4.0
# 64                  3.0                              4.0
# 75                  5.0                              5.0
# 103                 5.0                              5.0
# 110                 3.0                              4.0
# 117                 3.0                              3.0
# 120                 4.0                              4.0
# 132                 4.0                              4.0
# 139                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 5                        4                                5
# 9                        4                                5
# 23                       4                                4
# 24                       4                                4
# 26                       4                                5
# 36                       5                                5
# 39                       4                                4
# 45                       3                                4
# 64                       4                                3
# 75                       5                                5
# 103                      5                                5
# 110                      4                                5
# 117                      3                                5
# 120                      4                                5
# 132                      4                                4
# 139                      3                                4

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 0                1                           5             3
# 1                0                           5             3
# 2                0                           4             3
# 3                0                           4             1
# 4                1                           3             2
# ..             ...                         ...           ...
# 134              1                           5             1
# 135              1                           4             3
# 136              0                           3             4
# 137              1                           3             3
# 138              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 0                   3.0                              3.0
# 1                   3.0                              3.0
# 2                   3.0                              3.0
# 3                   3.0                              4.0
# 4                   4.0                              4.0
# ..                  ...                              ...
# 134                 2.0                              5.0
# 135                 3.0                              3.0
# 136                 3.0                              3.0
# 137                 3.0                              5.0
# 138                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 0                        5                                3
# 1                        5                                3
# 2                        4                                4
# 3                        4                                5
# 4                        4                                5
# ..                     ...                              ...
# 134                      2                                4
# 135                      3                                4
# 136                      2                                3
# 137                      5                                5
# 138                      3                                4
#
# [124 rows x 7 columns]

# %%
# Unhappy/Happy is the class label: as per specifications, move the class label to the last column
# Save reference to column
class_label = df['Unhappy/Happy']
class_label
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 134    1
# 135    1
# 136    0
# 137    1
# 138    1
# Name: Unhappy/Happy, Length: 124, dtype: int64

# %%
# drop class label column
df.drop('Unhappy/Happy', axis=1, inplace=True)
df
# Out:
#      City Services Availability  Housing Cost  Quality of schools  \
# 0                             5             3                 3.0
# 1                             5             3                 3.0
# 2                             4             3                 3.0
# 3                             4             1                 3.0
# 4                             3             2                 4.0
# ..                          ...           ...                 ...
# 134                           5             1                 2.0
# 135                           4             3                 3.0
# 136                           3             4                 3.0
# 137                           3             3                 3.0
# 138                           3             3                 1.0
#
#      Community trust in local police  Community Maintenance  \
# 0                                3.0                      5
# 1                                3.0                      5
# 2                                3.0                      4
# 3                                4.0                      4
# 4                                4.0                      4
# ..                               ...                    ...
# 134                              5.0                      2
# 135                              3.0                      3
# 136                              3.0                      2
# 137                              5.0                      5
# 138                              3.0                      3
#
#      Availability of Community Room
# 0                                  3
# 1                                  3
# 2                                  4
# 3                                  5
# 4                                  5
# ..                               ...
# 134                                4
# 135                                4
# 136                                3
# 137                                5
# 138                                4
#
# [124 rows x 6 columns]

# %%
# add new column to end of table
df['Unhappy/Happy'] = class_label
df
# Out:
#      City Services Availability  Housing Cost  Quality of schools  \
# 0                             5             3                 3.0
# 1                             5             3                 3.0
# 2                             4             3                 3.0
# 3                             4             1                 3.0
# 4                             3             2                 4.0
# ..                          ...           ...                 ...
# 134                           5             1                 2.0
# 135                           4             3                 3.0
# 136                           3             4                 3.0
# 137                           3             3                 3.0
# 138                           3             3                 1.0
#
#      Community trust in local police  Community Maintenance  \
# 0                                3.0                      5
# 1                                3.0                      5
# 2                                3.0                      4
# 3                                4.0                      4
# 4                                4.0                      4
# ..                               ...                    ...
# 134                              5.0                      2
# 135                              3.0                      3
# 136                              3.0                      2
# 137                              5.0                      5
# 138                              3.0                      3
#
#      Availability of Community Room   Unhappy/Happy
# 0                                  3              1
# 1                                  3              0
# 2                                  4              0
# 3                                  5              0
# 4                                  5              1
# ..                               ...            ...
# 134                                4              1
# 135                                4              1
# 136                                3              0
# 137                                5              1
# 138                                4              1
#
# [124 rows x 7 columns]

# %%
# Split the dataframe to training set and dataset.
# Using an 80% - 20% split

df_train = df.sample(frac=0.8)
df_test = df.drop(df_train.index)

# %%
# reindex set, then print
# df_train.sort_index(ascending=True, inplace=True)
df_train.reset_index(drop=True, inplace=True)
df_train
# Out:
#     City Services Availability  Housing Cost  Quality of schools  \
# 0                            3             4                 3.0
# 1                            3             1                 2.0
# 2                            4             3                 4.0
# 3                            4             1                 3.0
# 4                            3             2                 3.0
# ..                         ...           ...                 ...
# 94                           5             2                 5.0
# 95                           5             1                 4.0
# 96                           5             3                 3.0
# 97                           4             3                 3.0
# 98                           5             1                 3.0
#
#     Community trust in local police  Community Maintenance  \
# 0                               3.0                      2
# 1                               2.0                      1
# 2                               4.0                      2
# 3                               1.0                      1
# 4                               3.0                      2
# ..                              ...                    ...
# 94                              5.0                      5
# 95                              3.0                      5
# 96                              4.0                      4
# 97                              3.0                      3
# 98                              3.0                      4
#
#     Availability of Community Room   Unhappy/Happy
# 0                                 3              0
# 1                                 3              0
# 2                                 4              0
# 3                                 4              1
# 4                                 3              0
# ..                              ...            ...
# 94                                3              1
# 95                                5              1
# 96                                4              0
# 97                                4              1
# 98                                4              1
#
# [99 rows x 7 columns]

# %%
# reindex the testset
df_test.reset_index(drop=True, inplace=True)
df_test
# Out:
#     City Services Availability  Housing Cost  Quality of schools  \
# 0                            3             2                 4.0
# 1                            4             1                 3.0
# 2                            4             3                 2.0
# 3                            4             4                 4.0
# 4                            5             5                 5.0
# 5                            5             1                 5.0
# 6                            5             4                 5.0
# 7                            5             5                 5.0
# 8                            3             3                 3.0
# 9                            3             4                 5.0
# 10                           5             4                 4.0
# 11                           3             1                 3.0
# 12                           4             1                 3.0
# 13                           4             1                 3.0
# 14                           5             1                 5.0
# 15                           5             3                 4.0
# 16                           5             3                 5.0
# 17                           5             2                 3.0
# 18                           3             2                 3.0
# 19                           5             3                 3.0
# 20                           5             4                 3.0
# 21                           3             2                 4.0
# 22                           5             3                 4.0
# 23                           5             1                 4.0
# 24                           5             1                 2.0
#
#     Community trust in local police  Community Maintenance  \
# 0                               4.0                      4
# 1                               4.0                      4
# 2                               4.0                      3
# 3                               4.0                      3
# 4                               2.0                      5
# 5                               5.0                      5
# 6                               5.0                      5
# 7                               5.0                      5
# 8                               3.0                      3
# 9                               4.0                      5
# 10                              3.0                      3
# 11                              2.0                      1
# 12                              5.0                      3
# 13                              2.0                      4
# 14                              3.0                      5
# 15                              4.0                      4
# 16                              4.0                      5
# 17                              4.0                      4
# 18                              5.0                      4
# 19                              3.0                      3
# 20                              3.0                      3
# 21                              3.0                      4
# 22                              5.0                      4
# 23                              3.0                      4
# 24                              4.0                      4
#
#     Availability of Community Room   Unhappy/Happy
# 0                                 5              1
# 1                                 3              0
# 2                                 4              1
# 3                                 4              0
# 4                                 5              0
# 5                                 5              1
# 6                                 5              1
# 7                                 5              1
# 8                                 4              0
# 9                                 4              0
# 10                                4              1
# 11                                2              0
# 12                                5              0
# 13                                4              0
# 14                                5              1
# 15                                4              1
# 16                                5              0
# 17                                3              1
# 18                                3              0
# 19                                5              1
# 20                                5              0
# 21                                4              1
# 22                                5              0
# 23                                5              1
# 24                                5              0

# %%
# Proccess the data such that relevent features are kept and irrelevent features are dropped
# Create a correlation matrix for the Training set
correlation_matrix = df_train.corr()
correlation_matrix
# Out:
#                                  City Services Availability  Housing Cost  \
# City Services Availability                         1.000000      0.054982
# Housing Cost                                       0.054982      1.000000
# Quality of schools                                 0.291865      0.140136
# Community trust in local police                    0.112990      0.113677
# Community Maintenance                              0.419571     -0.024130
# Availability of Community Room                     0.378189     -0.093070
# Unhappy/Happy                                      0.334221      0.052480
#
#                                  Quality of schools  \
# City Services Availability                 0.291865
# Housing Cost                               0.140136
# Quality of schools                         1.000000
# Community trust in local police            0.273560
# Community Maintenance                      0.173555
# Availability of Community Room             0.083878
# Unhappy/Happy                              0.173187
#
#                                  Community trust in local police  \
# City Services Availability                              0.112990
# Housing Cost                                            0.113677
# Quality of schools                                      0.273560
# Community trust in local police                         1.000000
# Community Maintenance                                   0.227888
# Availability of Community Room                          0.201244
# Unhappy/Happy                                           0.150268
#
#                                  Community Maintenance  \
# City Services Availability                    0.419571
# Housing Cost                                 -0.024130
# Quality of schools                            0.173555
# Community trust in local police               0.227888
# Community Maintenance                         1.000000
# Availability of Community Room                0.256598
# Unhappy/Happy                                 0.196699
#
#                                  Availability of Community Room   \
# City Services Availability                              0.378189
# Housing Cost                                           -0.093070
# Quality of schools                                      0.083878
# Community trust in local police                         0.201244
# Community Maintenance                                   0.256598
# Availability of Community Room                          1.000000
# Unhappy/Happy                                           0.193326
#
#                                  Unhappy/Happy
# City Services Availability            0.334221
# Housing Cost                          0.052480
# Quality of schools                    0.173187
# Community trust in local police       0.150268
# Community Maintenance                 0.196699
# Availability of Community Room        0.193326
# Unhappy/Happy                         1.000000

# %%
class KNN:
    def __init__(self, k):
        self.k = k
        
    def fit(self, X_train, Y_train):
        self.x_train = X_train
        self.y_train = Y_train
        
    # Calculates the distance between two points
    def euclidian_distance(self, x1, x2):
        distance = 0.0
        
        for i in range(len(x1)):
            distance += (x1[i]-x2[i])**2
            
        return np.sqrt(distance)
        
    def predict(self, X_test):
        predictions = [self._predict(x) for x in X_test]
        return predictions
    
    def _predict(self, x_point):
        print(x_point)
        # Compute Distance
        distances = [euclidian_distance(x_point, X_train) for X_train in self.x_train]
        
        # Closest K
        #np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        
        # majority vote
        most_common = Counter(k_nearest_labels).most_common()
        return most_common

# %%
# For training set, seperate x and y values

x_train = df_train.drop('Unhappy/Happy', axis=1)
y_train = df_train["Unhappy/Happy"]

# %%
# Do same for test set

x_test = df_test.drop('Unhappy/Happy', axis=1)
y_test = df_test["Unhappy/Happy"]

# %%
# Make nearest_neighbors class object
nearest_neighbors = KNN(k=5)
nearest_neighbors.fit(x_train, y_train)

a = nearest_neighbors.euclidian_distance(x_train.iloc[0], x_train.iloc[1])

print(a)
# Out:
# 3.4641016151377544
