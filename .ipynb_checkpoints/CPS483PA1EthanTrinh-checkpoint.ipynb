# %%
# Python Version 3.10.6
import numpy as np # Numpy 1.24.2
import pandas as pd # Pandas 1.5.3
from collections import Counter # 
import matplotlib.pyplot as plot # Matplotlib 3.7.0

# %%
# Import and reorder CSV file
# Row 0 was skipped because row 0 was the row label

df = pd.read_csv('HappinessData-1.csv', skiprows=[0], names=['Unhappy/Happy', 'City Services Availability', 'Housing Cost', 
                                                            'Quality of schools', 'Community trust in local police', 
                                                            'Community Maintenance', 'Availability of Community Room '])
df
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 0                1                           5             3
# 1                0                           5             3
# 2                0                           4             3
# 3                0                           4             1
# 4                1                           3             2
# ..             ...                         ...           ...
# 135              1                           4             3
# 136              0                           3             4
# 137              1                           3             3
# 138              1                           3             3
# 139              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 0                   3.0                              3.0
# 1                   3.0                              3.0
# 2                   3.0                              3.0
# 3                   3.0                              4.0
# 4                   4.0                              4.0
# ..                  ...                              ...
# 135                 3.0                              3.0
# 136                 3.0                              3.0
# 137                 3.0                              5.0
# 138                 1.0                              3.0
# 139                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 0                        5                                3
# 1                        5                                3
# 2                        4                                4
# 3                        4                                5
# 4                        4                                5
# ..                     ...                              ...
# 135                      3                                4
# 136                      2                                3
# 137                      5                                5
# 138                      3                                4
# 139                      3                                4
#
# [140 rows x 7 columns]

# %%
# Process data for any NaN
# First locate all NaN in dataset
nan_row = df[df.isnull().any(axis=1)]
nan_row
# Out:
#     Unhappy/Happy  City Services Availability  Housing Cost  \
# 5               1                           3             2
# 18              1                           5             3
# 27              1                           4             3
# 31              1                           5             3
#
#     Quality of schools  Community trust in local police  \
# 5                  4.0                              NaN
# 18                 4.0                              NaN
# 27                 NaN                              4.0
# 31                 NaN                              5.0
#
#     Community Maintenance  Availability of Community Room
# 5                       4                                5
# 18                      4                                5
# 27                      3                                4
# 31                      4                                5

# %%
# Calculate Mean and Median of each column
# Analyze data and figure out best value to fill NaN
print(df.mean(numeric_only=True))
print("\n")
print(df.median(numeric_only=True))
# Out:
# Unhappy/Happy                      0.535714
# City Services Availability         4.321429
# Housing Cost                       2.542857
# Quality of schools                 3.253623
# Community trust in local police    3.695652
# Community Maintenance              3.600000
# Availability of Community Room     4.221429
# dtype: float64
#
#
# Unhappy/Happy                      1.0
# City Services Availability         5.0
# Housing Cost                       3.0
# Quality of schools                 3.0
# Community trust in local police    4.0
# Community Maintenance              4.0
# Availability of Community Room     4.0
# dtype: float64

# %%
# Looking at the data, Mean, Median and Mode are all close enough to each other
# Replace NaN with Median, because unlike Mean (Median is a whole number and is based on frequency)

df = df.fillna(df.median())

# Check for nan rows 1 more time
nan_row2 = df[df.isnull().any(axis=1)]
nan_row2
# Out:
# Empty DataFrame
# Columns: [Unhappy/Happy, City Services Availability, Housing Cost, Quality of schools, Community trust in local police, Community Maintenance, Availability of Community Room ]
# Index: []

# %%
# Remove Duplicate rows in the data
# First find all of the duplicated rows

duplicateRows = df[df.duplicated()]
duplicateRows
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 5                1                           3             2
# 9                1                           5             3
# 23               1                           5             1
# 24               1                           5             1
# 26               1                           5             2
# 36               1                           5             2
# 39               1                           4             1
# 45               1                           4             3
# 64               0                           4             1
# 75               1                           5             5
# 103              1                           5             1
# 110              1                           5             3
# 117              0                           5             4
# 120              1                           5             4
# 132              0                           4             2
# 139              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 5                   4.0                              4.0
# 9                   4.0                              3.0
# 23                  3.0                              3.0
# 24                  3.0                              3.0
# 26                  4.0                              3.0
# 36                  4.0                              4.0
# 39                  3.0                              4.0
# 45                  3.0                              4.0
# 64                  3.0                              4.0
# 75                  5.0                              5.0
# 103                 5.0                              5.0
# 110                 3.0                              4.0
# 117                 3.0                              3.0
# 120                 4.0                              4.0
# 132                 4.0                              4.0
# 139                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 5                        4                                5
# 9                        4                                5
# 23                       4                                4
# 24                       4                                4
# 26                       4                                5
# 36                       5                                5
# 39                       4                                4
# 45                       3                                4
# 64                       4                                3
# 75                       5                                5
# 103                      5                                5
# 110                      4                                5
# 117                      3                                5
# 120                      4                                5
# 132                      4                                4
# 139                      3                                4

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Unhappy/Happy  City Services Availability  Housing Cost  \
# 0                1                           5             3
# 1                0                           5             3
# 2                0                           4             3
# 3                0                           4             1
# 4                1                           3             2
# ..             ...                         ...           ...
# 134              1                           5             1
# 135              1                           4             3
# 136              0                           3             4
# 137              1                           3             3
# 138              1                           3             3
#
#      Quality of schools  Community trust in local police  \
# 0                   3.0                              3.0
# 1                   3.0                              3.0
# 2                   3.0                              3.0
# 3                   3.0                              4.0
# 4                   4.0                              4.0
# ..                  ...                              ...
# 134                 2.0                              5.0
# 135                 3.0                              3.0
# 136                 3.0                              3.0
# 137                 3.0                              5.0
# 138                 1.0                              3.0
#
#      Community Maintenance  Availability of Community Room
# 0                        5                                3
# 1                        5                                3
# 2                        4                                4
# 3                        4                                5
# 4                        4                                5
# ..                     ...                              ...
# 134                      2                                4
# 135                      3                                4
# 136                      2                                3
# 137                      5                                5
# 138                      3                                4
#
# [124 rows x 7 columns]

# %%
# Unhappy/Happy is the class label: as per specifications, move the class label to the last column
# Save reference to column
class_label = df['Unhappy/Happy']
class_label
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 134    1
# 135    1
# 136    0
# 137    1
# 138    1
# Name: Unhappy/Happy, Length: 124, dtype: int64

# %%
# drop class label column
df.drop('Unhappy/Happy', axis=1, inplace=True)
df
# Out:
#      City Services Availability  Housing Cost  Quality of schools  \
# 0                             5             3                 3.0
# 1                             5             3                 3.0
# 2                             4             3                 3.0
# 3                             4             1                 3.0
# 4                             3             2                 4.0
# ..                          ...           ...                 ...
# 134                           5             1                 2.0
# 135                           4             3                 3.0
# 136                           3             4                 3.0
# 137                           3             3                 3.0
# 138                           3             3                 1.0
#
#      Community trust in local police  Community Maintenance  \
# 0                                3.0                      5
# 1                                3.0                      5
# 2                                3.0                      4
# 3                                4.0                      4
# 4                                4.0                      4
# ..                               ...                    ...
# 134                              5.0                      2
# 135                              3.0                      3
# 136                              3.0                      2
# 137                              5.0                      5
# 138                              3.0                      3
#
#      Availability of Community Room
# 0                                  3
# 1                                  3
# 2                                  4
# 3                                  5
# 4                                  5
# ..                               ...
# 134                                4
# 135                                4
# 136                                3
# 137                                5
# 138                                4
#
# [124 rows x 6 columns]

# %%
# add new column to end of table
df['Unhappy/Happy'] = class_label
df
# Out:
#      City Services Availability  Housing Cost  Quality of schools  \
# 0                             5             3                 3.0
# 1                             5             3                 3.0
# 2                             4             3                 3.0
# 3                             4             1                 3.0
# 4                             3             2                 4.0
# ..                          ...           ...                 ...
# 134                           5             1                 2.0
# 135                           4             3                 3.0
# 136                           3             4                 3.0
# 137                           3             3                 3.0
# 138                           3             3                 1.0
#
#      Community trust in local police  Community Maintenance  \
# 0                                3.0                      5
# 1                                3.0                      5
# 2                                3.0                      4
# 3                                4.0                      4
# 4                                4.0                      4
# ..                               ...                    ...
# 134                              5.0                      2
# 135                              3.0                      3
# 136                              3.0                      2
# 137                              5.0                      5
# 138                              3.0                      3
#
#      Availability of Community Room   Unhappy/Happy
# 0                                  3              1
# 1                                  3              0
# 2                                  4              0
# 3                                  5              0
# 4                                  5              1
# ..                               ...            ...
# 134                                4              1
# 135                                4              1
# 136                                3              0
# 137                                5              1
# 138                                4              1
#
# [124 rows x 7 columns]

# %%
# Split the dataframe to training set and dataset.
# Using an 80% - 20% split

df_train = df.sample(frac=0.8)
df_test = df.drop(df_train.index)

# %%
# reindex set, then print
# df_train.sort_index(ascending=True, inplace=True)
df_train.reset_index(drop=True, inplace=True)
df_train
# Out:
#     City Services Availability  Housing Cost  Quality of schools  \
# 0                            5             2                 4.0
# 1                            5             2                 3.0
# 2                            3             2                 4.0
# 3                            5             3                 4.0
# 4                            4             4                 4.0
# ..                         ...           ...                 ...
# 94                           3             4                 3.0
# 95                           5             1                 2.0
# 96                           5             3                 4.0
# 97                           4             2                 4.0
# 98                           3             4                 3.0
#
#     Community trust in local police  Community Maintenance  \
# 0                               5.0                      4
# 1                               3.0                      3
# 2                               3.0                      4
# 3                               4.0                      4
# 4                               4.0                      3
# ..                              ...                    ...
# 94                              4.0                      1
# 95                              5.0                      2
# 96                              5.0                      4
# 97                              4.0                      4
# 98                              3.0                      2
#
#     Availability of Community Room   Unhappy/Happy
# 0                                 5              1
# 1                                 5              0
# 2                                 4              1
# 3                                 4              1
# 4                                 4              0
# ..                              ...            ...
# 94                                4              0
# 95                                4              1
# 96                                5              0
# 97                                4              1
# 98                                3              0
#
# [99 rows x 7 columns]

# %%
# reindex the testset
df_test.reset_index(drop=True, inplace=True)
df_test
# Out:
#     City Services Availability  Housing Cost  Quality of schools  \
# 0                            5             3                 3.0
# 1                            5             3                 4.0
# 2                            4             4                 3.0
# 3                            5             2                 3.0
# 4                            4             3                 3.0
# 5                            5             3                 4.0
# 6                            5             2                 4.0
# 7                            5             1                 1.0
# 8                            4             4                 3.0
# 9                            4             3                 3.0
# 10                           5             3                 3.0
# 11                           3             2                 3.0
# 12                           5             5                 5.0
# 13                           3             3                 3.0
# 14                           4             4                 3.0
# 15                           5             4                 5.0
# 16                           4             2                 3.0
# 17                           4             1                 3.0
# 18                           5             3                 5.0
# 19                           4             3                 3.0
# 20                           5             5                 1.0
# 21                           3             3                 3.0
# 22                           3             2                 3.0
# 23                           3             3                 3.0
# 24                           3             3                 1.0
#
#     Community trust in local police  Community Maintenance  \
# 0                               3.0                      5
# 1                               3.0                      4
# 2                               4.0                      2
# 3                               3.0                      3
# 4                               4.0                      2
# 5                               4.0                      4
# 6                               3.0                      4
# 7                               5.0                      3
# 8                               3.0                      2
# 9                               3.0                      3
# 10                              4.0                      3
# 11                              3.0                      4
# 12                              5.0                      5
# 13                              3.0                      3
# 14                              4.0                      3
# 15                              4.0                      5
# 16                              4.0                      3
# 17                              2.0                      4
# 18                              4.0                      5
# 19                              4.0                      4
# 20                              1.0                      5
# 21                              4.0                      2
# 22                              3.0                      2
# 23                              5.0                      5
# 24                              3.0                      3
#
#     Availability of Community Room   Unhappy/Happy
# 0                                 3              1
# 1                                 5              1
# 2                                 4              1
# 3                                 3              0
# 4                                 4              0
# 5                                 5              1
# 6                                 5              1
# 7                                 5              0
# 8                                 5              1
# 9                                 5              0
# 10                                3              0
# 11                                4              0
# 12                                5              1
# 13                                4              0
# 14                                3              0
# 15                                4              1
# 16                                3              1
# 17                                4              0
# 18                                5              0
# 19                                4              1
# 20                                1              1
# 21                                4              0
# 22                                3              0
# 23                                5              1
# 24                                4              1

# %%
# Proccess the data such that relevent features are kept and irrelevent features are dropped
# Create a correlation matrix for the Training set
correlation_matrix = df_train.corr()
correlation_matrix
# Out:
#                                  City Services Availability  Housing Cost  \
# City Services Availability                         1.000000      0.090621
# Housing Cost                                       0.090621      1.000000
# Quality of schools                                 0.263066      0.207764
# Community trust in local police                    0.128817      0.141135
# Community Maintenance                              0.395234     -0.019336
# Availability of Community Room                     0.525909      0.046668
# Unhappy/Happy                                      0.351324     -0.050241
#
#                                  Quality of schools  \
# City Services Availability                 0.263066
# Housing Cost                               0.207764
# Quality of schools                         1.000000
# Community trust in local police            0.213925
# Community Maintenance                      0.270573
# Availability of Community Room             0.068438
# Unhappy/Happy                              0.193076
#
#                                  Community trust in local police  \
# City Services Availability                              0.128817
# Housing Cost                                            0.141135
# Quality of schools                                      0.213925
# Community trust in local police                         1.000000
# Community Maintenance                                   0.311028
# Availability of Community Room                          0.106929
# Unhappy/Happy                                           0.175564
#
#                                  Community Maintenance  \
# City Services Availability                    0.395234
# Housing Cost                                 -0.019336
# Quality of schools                            0.270573
# Community trust in local police               0.311028
# Community Maintenance                         1.000000
# Availability of Community Room                0.373679
# Unhappy/Happy                                 0.147842
#
#                                  Availability of Community Room   \
# City Services Availability                              0.525909
# Housing Cost                                            0.046668
# Quality of schools                                      0.068438
# Community trust in local police                         0.106929
# Community Maintenance                                   0.373679
# Availability of Community Room                          1.000000
# Unhappy/Happy                                           0.231609
#
#                                  Unhappy/Happy
# City Services Availability            0.351324
# Housing Cost                         -0.050241
# Quality of schools                    0.193076
# Community trust in local police       0.175564
# Community Maintenance                 0.147842
# Availability of Community Room        0.231609
# Unhappy/Happy                         1.000000

# %%
class KNN:
    def __init__(self, k):
        self.k = k
        
    def fit(self, X_train, Y_train):
        self.x_train = X_train
        self.y_train = Y_train
        
    # Calculates the distance between two points
    def euclidian_distance(self, x_test_point, x_training_point):
        distance = 0.0
        
        for i in range(len(x_test_point)):
            distance += (x_test_point[i]-x_training_point[i])**2
            
        return np.sqrt(distance)
        
    def predict(self, x_test):
        #self.euclidian_distance(x_test.iloc[], self.x_train.iloc[0])
        #predictions = [self._predict(x_test.loc[i] for i in range(len(x_test)), )]
        
        #self._predict(x_test.loc[i])
        
        distance = []
        
        print(len(x_test))
        print(len(self.x_train))
        
        for i in range(len(x_test)):
            for j in range(len(self.x_train)):
                distance.append(self.euclidian_distance(x_test.loc[i], x_train.loc[j]))
        
        df_dist = pd.DataFrame(data=distance)
        return df_dist

        # Find nearest k

# %%
# For training set, seperate x and y values

x_train = df_train.drop('Unhappy/Happy', axis=1)
y_train = df_train["Unhappy/Happy"]

# %%
# Do same for test set

x_test = df_test.drop('Unhappy/Happy', axis=1)
y_test = df_test["Unhappy/Happy"]

# %%
# Make nearest_neighbors class object
nearest_neighbors = KNN(k=5)
nearest_neighbors.fit(x_train, y_train)

a = nearest_neighbors.euclidian_distance(x_train.iloc[0], x_train.iloc[1])

print(a)
# Out:
# 2.449489742783178

# %%
b = nearest_neighbors.predict(x_test)
b
# Out:
# 25
# 99
#              0
# 0     3.316625
# 1     3.000000
# 2     2.828427
# 3     2.000000
# 4     3.000000
# ...        ...
# 2470  3.162278
# 2471  3.741657
# 2472  4.358899
# 2473  3.605551
# 2474  2.645751
#
# [2475 rows x 1 columns]
